# %% [markdown]
# ## GenerateListings
#
# **Purpose**: Generates real estate listings using AI for the HomeMatch application.
#
# **Main Components**:
# - AI-powered listing generation (GPT-3.5)
# - Batch processing to handle token limits
# - CSV export functionality
#
# **Output**:
# - Creates `house_listings.csv` with property listings including:
#   - Neighborhood, Property Type, Price, Bedrooms, Bathrooms, House Size, Description, Neighborhood Description
#
# **Configuration**:
# - City: Lisbon
# - Price Range: €100,000 - €1,500,000
# - Batch Size: 10 listings per API call
# - Default: 100 listings
#
# **Prerequisites**:
# - Replace `"YOUR API KEY"` with your OpenAI API key
# - Install dependencies: `pip install -r requirements.txt`
#
# **Usage**:
# - Run all cells sequentially
# - Adjust `num_listings` parameter in the last cell to change the number of listings generated

# %%
import os
import pandas as pd
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage
from langchain.prompts import PromptTemplate
from io import StringIO



os.environ["OPENAI_API_KEY"] = "YOUR API KEY"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"


save_file_name = "house_listings.csv"
batch_size = 10 # generate listings in batches to bypass the token limit

# init llm
model_name = "gpt-3.5-turbo"
temperature = 1.0
llm = ChatOpenAI(model_name=model_name, temperature=temperature, max_tokens=4000)

# %%
# create house listings
def create_house_listings(num_listings=1):
    # Example: Template with variables that can be filled
    template_with_vars = """
    Generate a real estate listing in only one city {city} with the following requirements:

    - Price range: {price_range}
    - Property type: {property_type}
    - Bedrooms: from 1 to 5
    - Bathrooms: from 1 to 3


    The content field should contain a JSON object with these keys:
    - Neighborhood: unique neighborhood name
    - Property Type: property type
    - Price: price as number (include € symbol in the value)
    - Bedrooms: number
    - Bathrooms: number
    - House Size: size in sqm (include sqm symbol in the value) 
    - Description: detailed property description, 1-2 sentences
    - Neighborhood Description: neighborhood description, 1-2 sentences

    Generate {num_listings_gen} listings.
    Make the listing unique and appealing. 
    Return the listing as a CSV list of listings.
    IMPORTANT: All fields that contain commas must be enclosed in double quotes. For example: "€750,000" or "A beautiful apartment, with modern amenities."
    """

    # Create the PromptTemplate
    prompt = PromptTemplate(
        input_variables=["city", "price_range", "property_type", "num_listings_gen"],
        template=template_with_vars
    )

    # Store values in a dictionary (this is what you'll unpack)
    prompt_vars = {
        "city": "Lisbon",
        "price_range": "€100,000 - €1,500,000",
        "property_type": "Apartment, House",
        "num_listings_gen": batch_size,
    }

    all_listings = []
    header_written = False

    # Format the template using ** to unpack the dictionary
    formatted_prompt = prompt.format(**prompt_vars)
    for i in range(0, num_listings, batch_size):
        # running in batches to bypass the token limit 
        response = llm([HumanMessage(content=formatted_prompt)])
        print("running for interval", i, "to", i+batch_size)

        # Clean up the response (remove markdown code blocks if present)
        csv_content = response.content.strip()
        if csv_content.startswith("```csv"):
            csv_content = csv_content[7:]
        if csv_content.startswith("```"):
            csv_content = csv_content[3:]
        if csv_content.endswith("```"):
            csv_content = csv_content[:-3]
        
        # Combine results
        lines = csv_content.strip().split('\n')
        if not header_written and len(lines) > 0:
            all_listings.append(lines[0])  # Header
            header_written = True
            if len(lines) > 1:
                all_listings.extend(lines[1:])  # Data rows
        elif len(lines) > 1:
            all_listings.extend(lines[1:])  # Skip header, add data rows
    
    return '\n'.join(all_listings)

# %%
# save the listings to a csv file
def save_listings_csv(listings):
    # Try to parse, skip bad lines automatically
    try:
        df = pd.read_csv(StringIO(listings), on_bad_lines='skip')
    except pd.errors.ParserError:
        # If still fails, remove last line and try again
        lines = listings.strip().split('\n')
        if len(lines) > 1:
            listings = '\n'.join(lines[:-1])
        df = pd.read_csv(StringIO(listings), on_bad_lines='skip')
    
    # Remove last entry if it doesn't have all 8 columns
    if len(df) > 0 and len(df.columns) == 8:
        last_row = df.iloc[-1]
        if last_row.isna().any() or (last_row == '').any():
            df = df.iloc[:-1]  # Remove incomplete last entry
    
    # Save with proper quoting to handle commas in values
    df.to_csv(save_file_name, index=True)
    return df

# %%
# run this to create the listings
listings = create_house_listings(num_listings=100)
print(listings)
save_listings_csv(listings)
# Out:
# running for interval 0 to 10
# running for interval 10 to 20
# running for interval 20 to 30
# running for interval 30 to 40
# running for interval 40 to 50
# running for interval 50 to 60
# running for interval 60 to 70
# running for interval 70 to 80
# running for interval 80 to 90
# running for interval 90 to 100
# Neighborhood,Property Type,Price,Bedrooms,Bathrooms,House Size,Description,Neighborhood Description
# "Alfama","Apartment","€150,000",1,1,"50 sqm","Charming one-bedroom apartment with views of the historic Alfama district. Perfect for a cozy city retreat.","Alfama is a picturesque neighborhood known for its narrow streets, Fado music, and stunning views of the Tagus River."
# "Chiado","House","€1,200,000",3,2,"200 sqm","Beautiful three-bedroom house with modern amenities and a rooftop terrace overlooking the city. Ideal for entertaining guests and enjoying the Lisbon lifestyle.","Chiado is a trendy neighborhood filled with boutique shops, cafes, and art galleries, making it a vibrant cultural hub in Lisbon."
# "Baixa","Apartment","€350,000",2,1,"80 sqm","Recently renovated two-bedroom apartment in the heart of Baixa. Bright and spacious living area with high ceilings and traditional Portuguese tiles.","Baixa is Lisbon's downtown area, known for its grand plazas, historic architecture, and bustling shopping streets."
# "Estrela","House","€950,000",4,3,"300 sqm","Stunning four-bedroom house with a private garden and swimming pool in the prestigious Estrela neighborhood. Impeccably designed with luxury finishes throughout.","Estrela is an upscale residential area known for its beautiful gardens, historic mansions, and tranquil atmosphere, offering a peaceful retreat from the city buzz."
# "Campo de Ourique","Apartment","€280,000",1,1,"65 sqm","Cozy one-bedroom apartment in the vibrant Campo de Ourique district. Close to trendy cafes, restaurants, and local markets, offering a true taste of Lisbon living.","Campo de Ourique is a lively neighborhood with a strong sense of community, known for its historic charm, leafy streets, and cultural attractions."
# "Parque das Nações","House","€1,500,000",5,3,"400 sqm","Luxurious five-bedroom house with waterfront views in Parque das Nações. Spacious living areas, modern kitchen, and a private dock for boat access.","Parque das Nações is a modern waterfront district, home to the Expo'98 site, world-class restaurants, and entertainment venues, offering a cosmopolitan lifestyle by the river."
# "Bairro Alto","Apartment","€200,000",1,1,"45 sqm","Quaint one-bedroom apartment in the vibrant Bairro Alto neighborhood. Close to trendy bars, restaurants, and cultural attractions, perfect for those seeking a lively urban experience.","Bairro Alto is Lisbon's nightlife hotspot, famous for its lively atmosphere, street art, and eclectic mix of shops, making it a popular destination for young creatives and music lovers."
# "Areeiro","House","€800,000",3,2,"250 sqm","Spacious three-bedroom house with a garden and garage in the family-friendly Areeiro neighborhood. Close to schools, parks, and public transport, ideal for growing families.","Areeiro is a residential area known for its quiet streets, green spaces, and local commerce, offering a relaxed suburban lifestyle in the heart of Lisbon."
# "Príncipe Real","Apartment","€400,000",2,2,"90 sqm","Modern two-bedroom apartment with a balcony in the trendy Príncipe Real neighborhood. Stylish design, high-end finishes, and proximity to upscale shops and restaurants.","Príncipe Real is a fashionable district known for its upscale boutiques, art galleries, and leafy gardens, offering a sophisticated lifestyle with a bohemian flair."
# "Santos","House","€1,000,000",4,3,"280 sqm","Elegant four-bedroom house with a rooftop terrace in the historic Santos district. Classic architecture, spacious interior, and stunning river views.","Santos is a charming waterfront neighborhood known for its historic mansions, trendy bars, and art scene, offering a blend of traditional charm and modern amenities."
# "Baixa",Apartment,"€450,000",2,2,"80 sqm","Modern apartment with stunning river views, located in the heart of Lisbon's historic Baixa district.","Baixa is known for its lively atmosphere, charming cobblestone streets, and proximity to many shops and restaurants."
# "Alfama",House,"€800,000",3,3,"150 sqm","Beautiful traditional Portuguese house with a rooftop terrace overlooking the Alfama district, perfect for outdoor entertaining.","Alfama is one of Lisbon's oldest neighborhoods, known for its narrow alleys, historic buildings, and Fado music scene."
# "Chiado",Apartment,"€600,000",1,1,"65 sqm","Chic and stylish apartment in the trendy Chiado neighborhood, close to upscale boutiques and cafes.","Chiado is a fashionable district known for its vibrant cultural scene, elegant architecture, and bustling nightlife."
# "Belém",House,"€1,200,000",4,2,"200 sqm","Spacious family home with a garden and backyard pool in the peaceful suburb of Belém, perfect for outdoor relaxation.","Belém is famous for its historic monuments, including the stunning Jerónimos Monastery and Belém Tower, and its tranquil waterfront setting."
# "Príncipe Real",Apartment,"€350,000",1,1,"55 sqm","Cozy apartment with balcony overlooking the leafy Príncipe Real square, known for its trendy cafes and boutique shopping.","Príncipe Real is a fashionable and upscale neighborhood, popular with young professionals and artists, with a vibrant cultural scene."
# "Avenida da Liberdade",House,"€1,500,000",5,3,"250 sqm","Luxurious townhouse with a private elevator and rooftop terrace on Lisbon's prestigious Avenida da Liberdade, offering panoramic city views.","Avenida da Liberdade is Lisbon's most exclusive boulevard, lined with luxury boutiques, upscale restaurants, and historic theaters."
# "Bairro Alto",Apartment,"€250,000",1,1,"45 sqm","Quaint apartment in the bohemian Bairro Alto neighborhood, surrounded by trendy bars, restaurants, and art galleries.","Bairro Alto is the city's vibrant nightlife district, known for its lively street parties, colorful street art, and eclectic mix of residents."
# "Campo de Ourique",House,"€950,000",4,2,"180 sqm","Renovated townhouse with a garden and patio in the family-friendly neighborhood of Campo de Ourique, close to parks and schools.","Campo de Ourique is a charming residential area with a village-like atmosphere, offering a mix of local shops, cafes, and green spaces."
# "Parque das Nações",Apartment,"€500,000",2,2,"90 sqm","Modern waterfront apartment in the futuristic Parque das Nações district, with access to parks, shopping, and entertainment venues.","Parque das Nações is a contemporary neighborhood built for Expo '98, featuring cutting-edge architecture, riverfront promenades, and the iconic Vasco da Gama Tower."
# "Estrela",House,"€700,000",3,2,"160 sqm","Elegant townhouse with a terrace and garden in the upscale Estrela district, known for its grand mansions and historic palaces.","Estrela is a prestigious neighborhood with leafy boulevards, cultural attractions like the Basilica and Jardim da Estrela, and a peaceful ambiance perfect for families."
# "Baixa",Apartment,"€350,000",2,1,"85 sqm","Stunning 2 bedroom apartment in the heart of Baixa, featuring modern finishes and a spacious layout. Ideal for city living with easy access to shops and restaurants.","Baixa is known for its charming cobblestone streets, historic buildings, and vibrant atmosphere."
# "Chiado",House,"€1,200,000",4,3,"220 sqm","Luxurious 4 bedroom house in Chiado, boasting high ceilings, a private garden, and panoramic views of the city. Perfect for those seeking a sophisticated urban retreat.","Chiado is a trendy district known for its upscale shopping, art galleries, and lively nightlife scene."
# "Belém",Apartment,"€500,000",3,2,"110 sqm","Beautiful 3 bedroom apartment in Belém, featuring a modern kitchen, spacious living areas, and a balcony with river views. Perfect for those who appreciate a mix of historical charm and contemporary design.","Belém is a historic neighborhood famous for its iconic landmarks, including the Jerónimos Monastery and Belém Tower, as well as its delicious pastel de nata."
# "Alfama",House,"€800,000",3,2,"160 sqm","Charming 3 bedroom house in Alfama, with traditional Portuguese tiles, a rooftop terrace, and stunning views of the river. Ideal for those who want to experience the old-world charm of Lisbon.","Alfama is Lisbon's oldest district, known for its narrow streets, Fado music, and historic buildings that transport you back in time."
# "Avenidas Novas",Apartment,"€650,000",2,2,"95 sqm","Modern 2 bedroom apartment in Avenidas Novas, with high-end finishes, a sleek design, and a communal rooftop pool. Perfect for those who enjoy a contemporary lifestyle in a central location.","Avenidas Novas is a residential and commercial district known for its wide avenues, upscale shops, and diverse dining options."
# "Campo de Ourique",House,"€950,000",5,3,"200 sqm","Spacious 5 bedroom house in Campo de Ourique, featuring a private garden, a wine cellar, and a cozy fireplace. Ideal for families looking for a peaceful retreat in the city.","Campo de Ourique is a charming neighborhood known for its tree-lined streets, local markets, and a relaxed atmosphere away from the tourist crowds."
# "Parque das Nações",Apartment,"€400,000",1,1,"70 sqm","Cozy 1 bedroom apartment in Parque das Nações, with a waterfront view, modern amenities, and access to a communal gym. Perfect for young professionals or couples looking for a contemporary urban lifestyle.","Parque das Nações is a modern district built for Expo '98, featuring sleek architecture, riverfront promenades, and a vibrant cultural scene."
# "Príncipe Real",House,"€1,300,000",4,2,"180 sqm","Elegant 4 bedroom house in Príncipe Real, with a private terrace, antique furniture, and original artwork. Ideal for those with a taste for luxury and style in a prestigious location.","Príncipe Real is a sophisticated neighborhood known for its upscale boutiques, lush gardens, and vibrant LGBTQ-friendly community."
# "Bairro Alto",Apartment,"€300,000",1,1,"50 sqm","Quaint 1 bedroom apartment in Bairro Alto, with exposed wooden beams, a cozy fireplace, and a balcony overlooking the bustling streets below. Perfect for those who want to experience the vibrant nightlife of Lisbon.","Bairro Alto is a lively district known for its eclectic mix of bars, restaurants, and live music venues, making it a popular destination for locals and tourists alike."
# "Estrela",House,"€1,000,000",3,2,"150 sqm","Stunning 3 bedroom house in Estrela, featuring a landscaped garden, a rooftop terrace, and panoramic views of the city. Ideal for those seeking a peaceful retreat with easy access to amenities and green spaces.","Estrela is a picturesque neighborhood known for its leafy parks, historic mansions, and tranquil atmosphere, offering a perfect blend of city living and natural beauty."
# "Baixa","Apartment","€275,000","2","1","90 sqm","Modern apartment in the heart of historic Baixa, overlooking the charming streets.","Baixa is known for its bustling atmosphere, trendy shops, and vibrant nightlife."
# "Chiado","House","€1,200,000","4","2","200 sqm","Spacious townhouse with a private garden in the upscale neighborhood of Chiado.","Chiado is a cultural hub with art galleries, theaters, and designer boutiques."
# "Alfama","Apartment","€150,000","1","1","50 sqm","Cozy one-bedroom apartment with stunning views of the river in the picturesque Alfama district.","Alfama is known for its narrow cobblestone streets, Fado music, and traditional restaurants."
# "Avenida da Liberdade","House","€900,000","3","3","150 sqm","Luxurious townhouse with a rooftop terrace and panoramic views of Lisbon's iconic boulevard.","Avenida da Liberdade is the city's prestigious shopping district, lined with high-end stores and luxury hotels."
# "Príncipe Real","Apartment","€500,000","3","2","120 sqm","Elegant apartment in a historic building, featuring period details and modern amenities in the trendy Príncipe Real neighborhood.","Príncipe Real is known for its leafy gardens, chic boutiques, and vibrant nightlife scene."
# "Belém","House","€1,300,000","5","3","250 sqm","Beautiful family home with a garden and pool in the historic district of Belém, famous for its monuments and museums.","Belém is a charming area with riverside promenades, scenic waterfront, and delicious pastries shops."
# "Campo de Ourique","Apartment","€350,000","2","1","80 sqm","Bright and airy two-bedroom apartment in the peaceful residential neighborhood of Campo de Ourique.","Campo de Ourique offers a relaxed atmosphere, local markets, and cozy cafes."
# "Parque das Nações","House","€1,000,000","4","2","180 sqm","Modern waterfront house with a private dock and breathtaking views of the Tagus River in Parque das Nações.","Parque das Nações is a contemporary district with futuristic architecture, green spaces, and cultural venues."
# "Santos","Apartment","€400,000","2","2","100 sqm","Charming two-bedroom apartment in the bohemian neighborhood of Santos, close to art galleries and trendy bars.","Santos is a lively area with a creative vibe, antique shops, and a vibrant nightlife scene."
# "Estrela","House","€800,000","3","2","160 sqm","Renovated townhouse with a garden and terrace in the elegant Estrela district, known for its parks and palaces.","Estrela is a sophisticated neighborhood with majestic buildings, upscale restaurants, and tranquil green spaces."
# "Alfama",Apartment,"€280,000",2,1,"80 sqm","Charming apartment in the historic Alfama district, with stunning views of the river. Perfect for a couple or small family.","Alfama is known for its picturesque narrow streets, Fado music, and traditional restaurants."
# "Belém",House,"€950,000",3,2,"180 sqm","Spacious house located in the prestigious neighborhood of Belém, close to the famous Tower of Belém and the Jerónimos Monastery. Ideal for a growing family looking for a quiet yet central location.","Belém is a cultural hub, with museums, parks, and riverfront promenades. It's a great mix of history and modernity."
# "Chiado",Apartment,"€650,000",1,1,"60 sqm","Stylish apartment in the trendy Chiado district, filled with designer shops, cafes, and theaters. Perfect for a single professional or couple looking for a vibrant urban lifestyle.","Chiado is the heart of Lisbon's nightlife scene, with plenty of entertainment options and a bohemian atmosphere."
# "Avenida da Liberdade",House,"€1,200,000",4,3,"220 sqm","Luxurious house on Lisbon's most prestigious avenue, Avenida da Liberdade. Featuring modern design, high-end finishes, and a private garden. Perfect for a sophisticated family looking for comfort and elegance.","Avenida da Liberdade is known for its upscale shops, gourmet restaurants, and beautiful tree-lined boulevards. It's the epitome of luxury living in Lisbon."
# "Baixa",Apartment,"€400,000",2,2,"90 sqm","Modern apartment in the bustling Baixa district, filled with shops, restaurants, and cultural attractions. Ideal for a young couple or professionals looking to live in the heart of the city.","Baixa is the commercial and financial center of Lisbon, with lively pedestrian streets and historic architecture. It's a vibrant area with a mix of locals and tourists."
# "Campo de Ourique",House,"€850,000",3,2,"160 sqm","Traditional house in the residential neighborhood of Campo de Ourique, known for its local markets, cafes, and family-friendly atmosphere. Great for a family looking for a peaceful and authentic Lisbon experience.","Campo de Ourique is a charming district with tree-lined streets, cozy squares, and a sense of community. It's a hidden gem in Lisbon, away from the tourist crowds."
# "Estrela",Apartment,"€320,000",1,1,"50 sqm","Cozy apartment in the leafy neighborhood of Estrela, close to the beautiful Jardim da Estrela park and historic Basilica. Perfect for a single person or couple seeking a tranquil retreat in the city.","Estrela is a residential area with a village feel, offering a relaxing environment away from the hustle and bustle of central Lisbon. It's an ideal location for those who value peace and quiet."
# "Parque das Nações",House,"€1,500,000",5,3,"300 sqm","Spacious house in the modern Parque das Nações district, overlooking the Tagus River and Vasco da Gama Bridge. Featuring a private pool, garden, and high-quality finishes. Ideal for a large family looking for comfort and luxury.","Parque das Nações is a contemporary waterfront area with futuristic architecture, shopping centers, and waterfront promenades. It's a vibrant and cosmopolitan neighborhood, perfect for those who enjoy modern living."
# "Santos",Apartment,"€280,000",2,1,"75 sqm","Bright and airy apartment in the trendy Santos district, known for its art galleries, design stores, and vibrant nightlife. Suitable for young professionals or a couple looking for a dynamic urban lifestyle.","Santos is a lively area with a mix of traditional and modern elements, offering a range of dining and entertainment options. It's a vibrant neighborhood that attracts a creative and eclectic crowd."
# "Príncipe Real",House,"€1,100,000",4,2,"230 sqm","Elegant house in the upscale Príncipe Real neighborhood, known for its luxury boutiques, gourmet restaurants, and beautiful gardens. Featuring classic architecture, spacious rooms, and a private terrace. Ideal for a discerning family seeking sophistication and comfort.","Príncipe Real is a chic and sophisticated area popular with affluent residents and expats. It offers a high standard of living, with upscale amenities and a refined atmosphere."
# "Chiado","Apartment","€750,000","3","2","120 sqm","A modern and stylish apartment in the heart of Chiado, featuring high ceilings and stunning views of the city skyline.","Chiado is a trendy neighborhood known for its upscale shops, trendy cafes, and vibrant nightlife."
# "Alfama","House","€400,000","2","1","80 sqm","Charming traditional house with a rooftop terrace offering panoramic views of the historic Alfama district.","Alfama is Lisbon's oldest neighborhood, characterized by narrow winding streets, colorful houses, and traditional Fado music venues."
# "Areeiro","Apartment","€300,000","1","1","65 sqm","Cozy one-bedroom apartment with a balcony overlooking the leafy streets of Areeiro, close to parks and public transport.","Areeiro is a peaceful residential neighborhood with a family-friendly atmosphere and a variety of amenities including shops and restaurants."
# "Belém","House","€1,200,000","4","3","200 sqm","Spacious and elegant house with a private garden and swimming pool, located in the historic district of Belém near iconic landmarks such as the Jerónimos Monastery.","Belém is a picturesque riverside neighborhood known for its cultural attractions, beautiful gardens, and delicious pastéis de nata."
# "Baixa","Apartment","€500,000","2","2","90 sqm","Bright and contemporary two-bedroom apartment in Baixa, just steps away from Lisbon's main square, Praça do Comércio.","Baixa is the bustling downtown district of Lisbon, famous for its grand plazas, historic architecture, and lively street performers."
# "Campo de Ourique","House","€800,000","3","2","150 sqm","Renovated townhouse with a charming courtyard in Campo de Ourique, a charming residential area known for its local markets and cozy eateries.","Campo de Ourique is a sought-after neighborhood offering a perfect blend of tranquility and urban amenities, with beautiful parks and good transport links."
# "Estrela","Apartment","€350,000","1","1","70 sqm","Quaint one-bedroom apartment in Estrela, featuring traditional Portuguese tiles and a sunny terrace with views of the Basilica da Estrela.","Estrela is a historic and upscale neighborhood with lush gardens, elegant mansions, and a relaxed vibe, perfect for those seeking a peaceful retreat in the city."
# "Parque das Nações","House","€1,500,000","5","3","250 sqm","Luxurious five-bedroom house in Parque das Nações overlooking the Tagus river, with a spacious garden and high-end finishes throughout.","Parque das Nações is a modern waterfront district known for its striking architecture, waterfront promenade, and vibrant cultural events."
# "Santos","Apartment","€600,000","3","2","110 sqm","Stylish three-bedroom apartment in Santos with a sleek modern design, spacious living areas, and a private balcony with river views.","Santos is a trendy neighborhood known for its art galleries, hip cafes, and lively nightlife scene, attracting a young and creative crowd."
# "Marvila","House","€200,000","2","1","75 sqm","Quaint two-bedroom house in the up-and-coming neighborhood of Marvila, featuring a rooftop terrace with panoramic views of the city skyline.","Marvila is a rapidly transforming district with a mix of industrial heritage, art galleries, and innovative new developments, offering a unique blend of old and new."
# "Chiado",Apartment,"€650,000",3,2,"120 sqm","Luxurious apartment with high-end finishes and stunning views of the historic city center. Perfect for those seeking a chic urban lifestyle.","Chiado is known for its vibrant atmosphere, fashionable shops, and trendy cafés."
# "Alfama",House,"€400,000",2,1,"80 sqm","Quaint house with traditional Portuguese architecture and a charming courtyard. Ideal for a cozy retreat in this historic neighborhood.","Alfama is Lisbon's oldest district, filled with narrow winding streets, colorful houses, and Fado music echoing through the alleys."
# "Príncipe Real",Apartment,"€1,200,000",4,3,"200 sqm","Spacious and modern apartment with a private terrace and panoramic views of the city. Perfect for entertaining guests or enjoying peaceful evenings.","Príncipe Real is a trendy neighborhood known for its upscale boutiques, gourmet restaurants, and beautiful gardens."
# "Belém",House,"€950,000",5,2,"180 sqm","Elegant family home with a large garden and classic design features. Close to cultural attractions and waterfront promenades, perfect for those who appreciate historical charm.","Belém is a historic district renowned for its iconic monuments, such as the Jerónimos Monastery and the Belém Tower, offering a glimpse into Portugal's maritime past."
# "Avenidas Novas",Apartment,"€800,000",2,2,"150 sqm","Modern apartment in a prestigious location with stylish interiors and state-of-the-art amenities. Ideal for those seeking a contemporary urban lifestyle.","Avenidas Novas is a cosmopolitan area known for its wide tree-lined avenues, upscale shopping options, and cultural institutions like the Gulbenkian Museum."
# "Campo de Ourique",House,"€550,000",3,1,"120 sqm","Charming townhouse with a sunny terrace and period features, offering a cozy and welcoming living space. Perfect for those who appreciate a sense of community.","Campo de Ourique is a residential neighborhood with a village-like atmosphere, filled with traditional markets, local eateries, and green spaces like Jardim da Estrela."
# "Estrela",Apartment,"€350,000",1,1,"70 sqm","Bright and airy apartment in a historical building, featuring original details and a central location near parks and cultural attractions. Ideal for first-time buyers or investors.","Estrela is a leafy neighborhood known for its beautiful gardens, such as Jardim da Estrela, and elegant architecture, providing a tranquil escape from the city hustle."
# "Baixa",House,"€1,300,000",4,3,"220 sqm","Stunning townhouse with a rooftop terrace and refurbished interiors, blending traditional charm with contemporary comfort. Perfect for those who value luxurious living in the heart of Lisbon.","Baixa is Lisbon's bustling downtown district, lined with grand squares, historic buildings, and renowned shopping streets like Rua Augusta, offering a vibrant urban experience."
# "Parque das Nações",Apartment,"€1,000,000",3,2,"180 sqm","Sleek and modern apartment with waterfront views and access to exclusive amenities, designed for a sophisticated urban lifestyle. Ideal for those who seek a dynamic and cosmopolitan environment.","Parque das Nações is a futuristic neighborhood built for Expo '98, featuring cutting-edge architecture, leisure facilities, and a scenic promenade along the Tagus River, providing a unique living experience."
# "Santos",House,"€700,000",2,2,"130 sqm","Renovated townhouse with a charming courtyard and contemporary interiors, offering a blend of historic character and modern conveniences. Perfect for those who appreciate a mix of old and new in a vibrant neighborhood.","Santos is a lively district with a bohemian atmosphere, known for its trendy bars, art galleries, and cultural events, attracting a creative and eclectic crowd."
# "Alfama","Apartment","€300,000","2","1","80 sqm","Charming apartment with views of the river, perfect for a couple or small family.","Historic neighborhood with narrow streets and colorful buildings."
# "Chiado","House","€1,200,000","3","2","150 sqm","Beautiful townhouse with a rooftop terrace, ideal for entertaining guests.","Trendy area known for its designer boutiques and lively atmosphere."
# "Belem","Apartment","€500,000","3","2","100 sqm","Modern apartment near the waterfront, featuring high ceilings and natural light.","Cultural hotspot with historical monuments and delicious pastries."
# "Avenida da Liberdade","House","€1,500,000","4","3","200 sqm","Luxurious house with a private garden, perfect for a large family.","Upscale area with designer shops, theaters, and upscale restaurants."
# "Santos","Apartment","€400,000","1","1","60 sqm","Cozy apartment with a balcony overlooking the city, great for a single professional.","Bohemian neighborhood with trendy cafes and art galleries."
# "Baixa","House","€800,000","5","3","250 sqm","Spacious house with traditional Portuguese tiles, ideal for a multigenerational family.","Historic area with grand plazas, bustling markets, and iconic landmarks."
# "Campo de Ourique","Apartment","€350,000","2","2","75 sqm","Bright apartment with a modern kitchen, located in a peaceful residential area.","Family-friendly neighborhood with parks, schools, and local markets."
# "Principe Real","House","€1,000,000","4","3","180 sqm","Stunning house with a courtyard garden and original architectural features.","Trendy neighborhood with hip restaurants, stylish boutiques, and lush gardens."
# "Graça","Apartment","€250,000","1","1","50 sqm","Quaint apartment with views of the castle, perfect for a first-time buyer or investor.","Authentic area with narrow streets, traditional cafes, and stunning viewpoints."
# "Marques de Pombal","House","€1,300,000","5","2","220 sqm","Elegant townhouse with a wine cellar and rooftop terrace, ideal for entertaining.","Central location near the business district and upscale hotels."
# "Alfama","Apartment","€250,000","2","1","80 sqm","Charming apartment with views of the Tagus River, located in the historic neighborhood of Alfama.","Alfama is known for its narrow streets, colorful buildings, and Fado music."
# "Bairro Alto","House","€800,000","3","2","150 sqm","Beautiful three-bedroom house with a rooftop terrace offering panoramic views of Lisbon, located in the trendy neighborhood of Bairro Alto.","Bairro Alto is famous for its vibrant nightlife, trendy bars, and traditional Fado music."
# "Chiado","Apartment","€500,000","1","1","70 sqm","Cozy one-bedroom apartment in the heart of Chiado, with modern amenities and a stylish design.","Chiado is known for its upscale shopping, art galleries, and elegant cafes."
# "Baixa","House","€1,200,000","4","3","200 sqm","Spacious four-bedroom house with a garden, located in the historic Baixa district, offering a blend of traditional architecture and modern comfort.","Baixa is the bustling downtown area of Lisbon, known for its iconic squares, pedestrian streets, and historic buildings."
# "Belém","Apartment","€350,000","2","2","90 sqm","Two-bedroom apartment with river views in Belém, featuring a contemporary design and proximity to cultural landmarks like the Jerónimos Monastery.","Belém is a charming district famous for its pastel de nata, historic monuments, and scenic waterfront."
# "Parque das Nações","House","€1,450,000","5","3","250 sqm","Luxurious five-bedroom house with a private pool and garden in Parque das Nações, offering a modern living experience near the waterfront.","Parque das Nações is a modern district known for its futuristic architecture, shopping center, and waterfront promenade."
# "Campo de Ourique","Apartment","€300,000","1","1","60 sqm","Renovated one-bedroom apartment in Campo de Ourique, featuring a blend of traditional charm and contemporary comfort.","Campo de Ourique is a residential neighborhood with a village-like feel, offering a relaxed atmosphere and a variety of local shops and restaurants."
# "Santos","House","€1,100,000","4","2","180 sqm","Four-bedroom house with a terrace and city views in the vibrant neighborhood of Santos, offering a blend of historic charm and modern amenities.","Santos is a lively district known for its cultural attractions, trendy bars, and waterfront promenade along the Tagus River."
# "Avenida da Liberdade","Apartment","€700,000","3","2","120 sqm","Spacious three-bedroom apartment on Avenida da Liberdade, offering luxury living in the heart of Lisbon's prestigious shopping street.","Avenida da Liberdade is Lisbon's main boulevard, lined with designer boutiques, upscale restaurants, and lush greenery."
# "Graça","House","€950,000","3","3","170 sqm","Three-bedroom house with a rooftop terrace and stunning views of the city in the picturesque neighborhood of Graça, offering a mix of traditional and modern architecture.","Graça is a historic district known for its panoramic viewpoints, winding streets, and traditional Portuguese charm."
# "Alfama","Apartment","€250,000",2,1,"80 sqm","Charming apartment in the historic Alfama district, with stunning views of the river.","Alfama is known for its narrow streets, Fado music, and traditional architecture."
# "Chiado","House","€1,200,000",3,2,"200 sqm","Luxurious house in the heart of Chiado, renovated with high-end finishes and a private garden.","Chiado is a trendy neighborhood filled with upscale shops, cafes, and cultural attractions."
# "Campo de Ourique","Apartment","€350,000",1,1,"60 sqm","Cozy apartment in a peaceful residential area, perfect for a couple or single professional.","Campo de Ourique is a charming neighborhood known for its local markets, green spaces, and friendly atmosphere."
# "Avenidas Novas","House","€800,000",4,3,"300 sqm","Spacious family home with a backyard and garage, located in a prime location close to schools and amenities.","Avenidas Novas is a bustling area with wide avenues, shops, and restaurants, popular among residents and expats alike."
# "Bairro Alto","Apartment","€180,000",1,1,"50 sqm","Quaint apartment with traditional Portuguese tiles and a balcony overlooking the lively streets of Bairro Alto.","Bairro Alto is a vibrant neighborhood known for its nightlife, bars, and artistic vibe."
# "Estrela","House","€950,000",5,2,"250 sqm","Stunning villa with a rooftop terrace and panoramic views of the city, ideal for a large family or entertaining guests.","Estrela is an elegant district with beautiful gardens, historic palaces, and a peaceful ambiance."
# "Belem","Apartment","€300,000",2,2,"70 sqm","Modern apartment with river views and proximity to Belem's cultural attractions, perfect for urban professionals or investors.","Belem is a historic area with famous monuments, museums, and trendy cafes along the waterfront."
# "Santos","House","€1,100,000",3,2,"220 sqm","Renovated townhouse with a courtyard and designer interiors, located in the trendy neighborhood of Santos.","Santos is a lively district with a mix of traditional and modern architecture, popular among young professionals and creatives."
# "Parque das Nações","Apartment","€500,000",3,2,"90 sqm","Contemporary apartment in a waterfront development with access to parks, shops, and restaurants in Parque das Nações.","Parque das Nações is a modern district with a marina, cable car, and cultural events, perfect for families and outdoor enthusiasts."
# "Marvila","House","€400,000",4,3,"180 sqm","Spacious townhouse with a garden and garage, located in the up-and-coming neighborhood of Marvila, known for its creative community and industrial-chic vibe.","Marvila is a dynamic area with art galleries, breweries, and street art, attracting a diverse mix of residents and businesses."
#          Neighborhood Property Type       Price  Bedrooms  Bathrooms  \
# 0              Alfama     Apartment    €150,000         1          1
# 1              Chiado         House  €1,200,000         3          2
# 2               Baixa     Apartment    €350,000         2          1
# 3             Estrela         House    €950,000         4          3
# 4    Campo de Ourique     Apartment    €280,000         1          1
# ..                ...           ...         ...       ...        ...
# 95            Estrela         House    €950,000         5          2
# 96              Belem     Apartment    €300,000         2          2
# 97             Santos         House  €1,100,000         3          2
# 98  Parque das Nações     Apartment    €500,000         3          2
# 99            Marvila         House    €400,000         4          3
#
#    House Size                                        Description  \
# 0      50 sqm  Charming one-bedroom apartment with views of t...
# 1     200 sqm  Beautiful three-bedroom house with modern amen...
# 2      80 sqm  Recently renovated two-bedroom apartment in th...
# 3     300 sqm  Stunning four-bedroom house with a private gar...
# 4      65 sqm  Cozy one-bedroom apartment in the vibrant Camp...
# ..        ...                                                ...
# 95    250 sqm  Stunning villa with a rooftop terrace and pano...
# 96     70 sqm  Modern apartment with river views and proximit...
# 97    220 sqm  Renovated townhouse with a courtyard and desig...
# 98     90 sqm  Contemporary apartment in a waterfront develop...
# 99    180 sqm  Spacious townhouse with a garden and garage, l...
#
#                              Neighborhood Description
# 0   Alfama is a picturesque neighborhood known for...
# 1   Chiado is a trendy neighborhood filled with bo...
# 2   Baixa is Lisbon's downtown area, known for its...
# 3   Estrela is an upscale residential area known f...
# 4   Campo de Ourique is a lively neighborhood with...
# ..                                                ...
# 95  Estrela is an elegant district with beautiful ...
# 96  Belem is a historic area with famous monuments...
# 97  Santos is a lively district with a mix of trad...
# 98  Parque das Nações is a modern district with a ...
# 99  Marvila is a dynamic area with art galleries, ...
#
# [100 rows x 8 columns]
